# %% [markdown]
# # Problem Satement : To find how salary is varying with respect to other factors in HR Industry.

# %% [markdown]
# ## “The goal is to turn data into information and information into insight”.

# %% [markdown]
# ## Step 1 : Data Analysis Phase

# %% [markdown]
# The main aim of data analysis is to understand the data, now in first step im going to import required libraries and importing the dataset

# %%
# Importing the required libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")# to ignore warnings

# %%
# Importing the Dataset
df = pd.read_csv("C:/Users/ADESH/OneDrive/Desktop/dataset/New_data_Set.csv")

# %% [markdown]
# ###  Displaying the first ten and last ten rows

# %%
# Displying the first 10 rows of dataset and understanding the type of data 
df.head(10)
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
# 5    Male         0           No   Yes        Two year     Yes     No   23
# 6    Male         0          Yes    No        Two year     Yes     No   23
# 7  Female         0           No   Yes        One year     Yes     No   24
# 8  Female         1           No   Yes  Month-to-month     Yes    Yes   24
# 9    Male         0           No   Yes  Month-to-month     Yes     No   43
#
#        Salary     Base_pay       Bonus  Unit_Price    Volume  openingbalance  \
# ...

# %%
# Displying the Last 10 rows of dataset and understanding the type of data
df.tail(10)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4990    Male         0           No   Yes  Month-to-month      No     No   70
# 4991    Male         1           No   Yes        Two year      No     No   70
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# ...

# %% [markdown]
# ### Understanding Raw Data

# %% [markdown]
# -The given data is about product base company and we have information of employees which are work there.
#
# -The given raw dataset is about salarys of Male & Female employees and some related factors like We have age of that employee,Education background of that employee etc.
#
# -We have 'Unit sales'means unit sale made by the person & 'Unit price'The Unit price of that sale & 'Total sales' means total sales made by the person.
#
# -We have 'Bonus' which means amount received by a person as bonus for sales,'Base pay' which means Base pay of the employee this are some payment related data.
#
# -'Rating' column data shows that does emplyee get rating from their superiors or not & 'Billing' shows either person Subscribed to billing plans or not
#
# -An 'opening balance' is the amount of funds of our company has at the beginning of an accounting period.
#
# -A 'closing balance' is an amount of funds of our business has at the end of a particular chosen accounting period so we have period in months here
#
# -'low' means lowest balance allotted to person
#
# -'Months' are give the information related accounting period or duration of person emplyed with the company

# %%
# info of the data which include the columns, dtype of the column, non-null count(count of not null values)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
# looking the Null values in our dataset 
df.isnull().sum()
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales          8
# Months               0
# Education            0
# dtype: int64

# %% [markdown]
# Here we see that We have we have null values 3 columns which are base_pay,openingbalance,total_balance.

# %%
#Checking the shape of dataset
df.shape
# Out:
# (5000, 20)

# %% [markdown]
# We see that we have 5000 rows and 20 columns

# %%
#Checking the size of dataset
df.size
# Out:
# 100000

# %% [markdown]
# We have total 100000 records in our dataset

# %%
#To count the values of the Gender.
df['Gender'].value_counts()
# Out:
# Male      2528
# Female    2472
# Name: Gender, dtype: int64

# %% [markdown]
# In Gender data we have 2528 male employee's and 2472 female employee's.

# %%
#counting the values of the Business.
df['Business'].value_counts()
# Out:
# 0    4200
# 1     800
# Name: Business, dtype: int64

# %% [markdown]
# In buiseness column data have 4200 employee's with 0 business and 800 employee's with 1 business.

# %%
#counting the values of the Dependancies 
df['Dependancies'].value_counts()
# Out:
# No     3524
# Yes    1476
# Name: Dependancies, dtype: int64

# %% [markdown]
# In Dependancies data we have 3524 employee's with no dependancies and 1476 empolyee's with dependancies on them.

# %%
#To count the values of the Calls 
df['Calls'].value_counts()
# Out:
# Yes    4539
# No      461
# Name: Calls, dtype: int64

# %% [markdown]
# In calls data we have 4539 emplyees have authority to make calls and 461 dont have any authority to make calls

# %%
#counting the values of the salary Type
df['Type'].value_counts()
# Out:
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: Type, dtype: int64

# %% [markdown]
# In type of salary paid 2777 we have  Month-to-month settlement,1195 Two year settlement and 1028 with One year settlement.

# %%
#counting the values of the Billing(Subscribed to billing plans or no) 
df['Billing'].value_counts()
# Out:
# Yes    2956
# No     2044
# Name: Billing, dtype: int64

# %% [markdown]
# We have 2956 has Subscribed to billing plans and 2044 are not Subscribed to billing plans.

# %%
#To count the values of Rating
#To see if person has been given a rating by a superior or not
df['Rating'].value_counts()
# Out:
# No     3682
# Yes    1318
# Name: Rating, dtype: int64

# %% [markdown]
# In which we have 3682 employee's gives no rating by a superior and 1318 has been given a rating by a superior.

# %%
#counting the values of Education
#Educational background of an employee
df['Education'].value_counts()
# Out:
# PG                     2979
# Graduation             1980
# Intermediate             27
# High School or less      14
# Name: Education, dtype: int64

# %% [markdown]
#  In which we have 2979 PG background,1980 graduation background, 27 intermediate backgroung and 14 high school or less backgroung emplyees.

# %% [markdown]
# ### Now by looking towards the above steps I understand the all about our dataset .

# %% [markdown]
# # Handleing missing data

# %%
# We need to deal with missing data
df.isnull().sum()
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales          8
# Months               0
# Education            0
# dtype: int64

# %%
#Visualizing patterns in the missing data
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we see that openingbalance have 1476 values are missing and 23 values in base_pay are missing and only 8 values missing in total_sales.
#
# The missing values are very less this are negligible but we have to fix that missing values for getting better results.

# %% [markdown]
# ## Cleaning the data & Replacing missing values

# %%
# replacing missing values of openingbalance with mean of that column
df['openingbalance'] = df['openingbalance'].fillna(df['openingbalance'].mean())

# %%
# replacing missing values of Base_pay with mean of that column
df['Base_pay'] = df['Base_pay'].fillna(df['Base_pay'].mean())

# %% [markdown]
# Here we see that Total_sales column have object datatype we have chnage that dtype into float 64

# %% [markdown]
# Empty cells can potentially give us a wrong result either we have to replacing that blanck data or we have to remove this 8 rows.
#
# So I decided to replace that blank spaces with "NAN" value and then again replacing that "NAN" into mean of that column

# %%
df = df.replace(r'^\s*$', float(np.NaN), regex=True) # replacing blank spaces with "NAN" for ease of calculation

# %%
df.tail(10)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4990    Male         0           No   Yes  Month-to-month      No     No   70
# 4991    Male         1           No   Yes        Two year      No     No   70
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# ...

# %% [markdown]
# Now here we replace that blank cells with "NAN" value

# %%
df['Total_Sales'] = df['Total_Sales'].astype('float64')# changing the datatype object to float64

# %%
df.shape# checking the shape of dataset we ahave 5000 rows and 20 columns
# Out:
# (5000, 20)

# %%
df.isnull().sum()# checking the nullcount
# Out:
# Gender             0
# Business           0
# Dependancies       0
# Calls              0
# Type               0
# Billing            0
# Rating             0
# Age                0
# Salary             0
# Base_pay           0
# Bonus              0
# Unit_Price         0
# Volume             0
# openingbalance     0
# closingbalance     0
# low                0
# Unit_Sales         0
# Total_Sales       16
# Months             0
# Education          0
# dtype: int64

# %% [markdown]
# Here we see that in total_sales now we have 16 "NAN" values because we replace that blank spaces.

# %%
# Cross checking mean and mode values of Total sales column
a= df.Total_Sales.mode()
b= df.Total_Sales.mean()
print("Mode of Total_sales column:",a)
print("Mean of Total_sales column:",b)
# Out:
# Mode of Total_sales column: 0    19.45
# 1    19.75
# 2    20.15
# 3    20.20
# dtype: float64
# Mean of Total_sales column: 2272.3739767255197

# %% [markdown]
# Here we see that mean and mode both values are same is Total_sales column

# %%
# replacing missing values of total with mean of that column
df['Total_Sales'] = df['Total_Sales'].fillna(df['Total_Sales'].mean())

# %%
df.isnull().sum().any()# sanity checking
# Out:
# False

# %% [markdown]
# false means now we dont have any missing value

# %% [markdown]
# ## Summary Stats

# %%
df.describe()# It shows the statistical summary of our dataset
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   5000.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10112.342452  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33744.021630  4194.516950
# 50%       0.000000    52.000000  100579.378500  40231.751415  5028.968925
# 75%       0.000000    57.000000  116912.092475  46764.836975  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     5000.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %% [markdown]
# Now We have statistical summary of our dataset here we can see that mean,median(50%),min,max etc.

# %% [markdown]
# ### we choose first step as handling of missing data because at earlier we dont know about our raw data thats why before moving further we have to clean the data and have to change required datatypes.

# %% [markdown]
# # Step II :  Checking the Numerical features & distribution of that variables

# %%
df2 = df.select_dtypes(include=np.number)# viewing only numerical variables
df2.head()
# Out:
#    Business  Age   Salary  Base_pay     Bonus  Unit_Price    Volume  \
# 0         0   18  5089.00  2035.600  254.4500        3.77  21226600
# 1         0   19  5698.12  2279.248  284.9060        3.74  10462800
# 2         0   22  5896.65  2358.660  294.8325        3.89  18761000
# 3         1   21  6125.12  2450.048  306.2560        4.35  66130600
# 4         0   23  6245.00  2498.000  312.2500        4.34  26868200
#
#    openingbalance  closingbalance   low  Unit_Sales  Total_Sales  Months
# 0            3.75            3.76  3.65       18.25        18.80       0
# 1            3.85            3.68  3.65       18.40        18.85       0
# 2            4.23            4.29  3.72       18.70        18.90       0
# 3            4.26            4.31  3.83       18.75        19.00       0
# 4            4.79            4.41  4.08       18.80        19.05       1

# %% [markdown]
# above we can see that we have 13 numerical columns so we are going to check the distribution of that columns

# %% [markdown]
# ## Visualizing the numerical variables to see distribution

# %% [markdown]
# ## Visualizing Distribution using Histogram #1st Approach

# %%
# setting a grey background 
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# Ploting subplots with numerical variables
sns.histplot(data=df, x="Salary", kde=True, color="red", ax=axs[0, 0])
sns.histplot(data=df, x="Base_pay", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df, x="Bonus", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df, x="Age", kde=True, color="black", ax=axs[1, 1])
plt.show()

# %% [markdown]
# By using Histogram we see that 'Salary','Base_pay','Bonus','Age' this variables are normally distributed we see that bell a shape curve which means this variables are normally distributed.

# %%
# settong a grey background  
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with numerical variables
sns.histplot(data=df, x="Unit_Price", kde=True, color="darkred", ax=axs[0, 0])# histogram plot of unitprice 
sns.histplot(data=df, x="Unit_Sales", kde=True, color="olive", ax=axs[0, 1])# histogram plot of unit_sales
sns.histplot(data=df, x="openingbalance", kde=True, color="gold", ax=axs[1, 0])# histogram plot of openingbalance
sns.histplot(data=df, x="closingbalance", kde=True, color="teal", ax=axs[1, 1])# histogram plot of closingbalance

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
sns.histplot(data=df, x="low", kde=True, color="red", ax=axs[0])# histogram for low column 
sns.histplot(data=df, x="Total_Sales", kde=True, color="Navy", ax=axs[1])# histogram for Total_sales column
plt.show()

# %% [markdown]
# So our remaining columns like 'total_sales','low','openingbalance','closingbalance','unit_price', this variables are skewed towards the right.

# %% [markdown]
# ## Box plot to see distribution

# %%
# setting a grey background 
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with variables
sns.boxplot(data=df, x="Salary", color="Lime", ax=axs[0, 0])# boxplot to see Distribution of salary
sns.boxplot(data=df, x="Base_pay", color="olive", ax=axs[0, 1])# boxplot to see Distribution of base_pay
sns.boxplot(data=df, x="Bonus", color="gold", ax=axs[1, 0])# boxplot to see Distribution of bonus
sns.boxplot(data=df, x="Age", color="pink", ax=axs[1, 1])# boxplot to see Distribution of age
plt.show()

# %% [markdown]
# By using Boxplot we see that 'Salary','Base_pay','Bonus','Age' this variables are normally distributed we see that When the median is in the middle of the box, and the whiskers are about the same on both sides of the box, then the distribution is symmetric.

# %%
# settong a grey background  
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with all variables
sns.boxplot(data=df, x="Unit_Price", color="darkred", ax=axs[0, 0])# boxplot to see outliers of unitprice 
sns.boxplot(data=df, x="Unit_Sales", color="olive", ax=axs[0, 1])# boxplot to see outliers of unit_sales
sns.boxplot(data=df, x="openingbalance", color="gold", ax=axs[1, 0])# boxplot to see outliers of openingbalance
sns.boxplot(data=df, x="closingbalance", color="teal", ax=axs[1, 1])# boxplot to see outliers of closingbalance

plt.show()

# %%
# settong a grey background  
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with variables
sns.boxplot(data=df, x="low", color="red", ax=axs[0,0])# boxplot to see outliers of low column 
sns.boxplot(data=df, x="Total_Sales", color="Navy", ax=axs[0,1])# boxplot to see outliers of Total_sales column
sns.boxplot(data=df, x="Volume", color="Yellow", ax=axs[1,0])# boxplot to see outliers of volume column
sns.boxplot(data=df, x="Months", color="skyblue", ax=axs[1,1])# boxplot to see outliers of months column
plt.show()

# %% [markdown]
# So our remaining columns like 'total_sales','low','openingbalance','closingbalance','unit_price','Volume','Months' this variables are not symetric becuase we see that When the median is not in the middle of the box, and the whiskers are not about the same on both sides of the box, thats why the distribution is nonsymmetric.

# %% [markdown]
# ##    #3Statistical Approach QQplot

# %% [markdown]
# ### If the data is normally distributed, the points in the QQ-normal plot lie on a straight diagonal line.

# %%
# QQ plot for Salary
import pingouin as pg 
pg.qqplot(df['Salary'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is lie on the straight diagonal line which means our variable is normally distributed.

# %%
# QQ plot for Base_Pay
pg.qqplot(df['Base_pay'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is lie on the straight diagonal line which means our variable is normally distributed.

# %%
# QQ plot for Bonus
pg.qqplot(df['Bonus'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is lie on the straight diagonal line which means our variable is normally distributed.

# %%
# QQ plot for Age
pg.qqplot(df['Age'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is lie on the straight diagonal line which means our variable is normally distributed.

# %%
# QQ plot for Unit_Price
pg.qqplot(df['Unit_Price'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is not lie on the straight diagonal line which means our variable is not normally distributed.

# %%
# QQ plot for Unit_Sales
pg.qqplot(df['Unit_Sales'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is not lie on the straight diagonal line which means our variable is not normally distributed.

# %%
# QQ plot for Openingbalance
pg.qqplot(df['openingbalance'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is not lie on the straight diagonal line which means our variable is not normally distributed.

# %%
# QQ plot for Closing Balance
pg.qqplot(df['closingbalance'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is not lie on the straight diagonal line which means our variable is not normally distributed.

# %%
# QQ plot for Total_sales
pg.qqplot(df['Total_Sales'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is not lie on the straight diagonal line which means our variable is not normally distributed.

# %%
# QQ plot for Low
pg.qqplot(df['low'],dist ='norm')
# Out:
# <AxesSubplot:title={'center':'Q-Q Plot'}, xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# we see that most of the data is not lie on the straight diagonal line which means our variable is not normally distributed.

# %% [markdown]
# # Step III : Finding out the correlation between variables using spearman rank correlation

# %% [markdown]
# Pearson correlation assumes that the data we are comparing is normally distributed. When that assumption is not true, the correlation value is reflecting the true association. Spearman correlation does not assume that data is from a specific distribution, so it is a non-parametric correlation measure.
#
# Thats why we are going to use spearman rank correlation

# %%
df3 = df2.drop(['Business'],axis = 1)# Here I remove the business column becuase this variable comes under categorical feature
df3.head()
# Out:
#    Age   Salary  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0   18  5089.00  2035.600  254.4500        3.77  21226600            3.75
# 1   19  5698.12  2279.248  284.9060        3.74  10462800            3.85
# 2   22  5896.65  2358.660  294.8325        3.89  18761000            4.23
# 3   21  6125.12  2450.048  306.2560        4.35  66130600            4.26
# 4   23  6245.00  2498.000  312.2500        4.34  26868200            4.79
#
#    closingbalance   low  Unit_Sales  Total_Sales  Months
# 0            3.76  3.65       18.25        18.80       0
# 1            3.68  3.65       18.40        18.85       0
# 2            4.29  3.72       18.70        18.90       0
# 3            4.31  3.83       18.75        19.00       0
# 4            4.41  4.08       18.80        19.05       1

# %%
# Spearman rank correlation heatmap

df3.corr(method="spearman")# selecting the method as a sperman
plt.figure(figsize=(20,8))# setting the figuresize

heatmap = sns.heatmap(df3.corr(method = 'spearman').round(3), vmin=-1, 
vmax=1, annot=True)# annot = True means writting the data value in each cell.

font2= {'family':'serif','color':'green','size':20}
plt.title("Spearman Rank Correlation",font2)
plt.show()# displaying heatmap

# %% [markdown]
# Spearman's correlation assesses monotonic relationships, Monotomc relationship means a scenario in which the size of one variable increases as the other variables also increases, or where the size of one variable increases as the other variable also decreases

# %%
#correlation between the variables.
df3.corr(method = "spearman")
# Out:
#                      Age    Salary  Base_pay     Bonus  Unit_Price    Volume  \
# Age             1.000000  0.202282  0.192930  0.202282    0.128266 -0.039345
# Salary          0.202282  1.000000  0.994006  1.000000    0.811713 -0.390488
# Base_pay        0.192930  0.994006  1.000000  0.994006    0.808311 -0.390056
# Bonus           0.202282  1.000000  0.994006  1.000000    0.811713 -0.390488
# Unit_Price      0.128266  0.811713  0.808311  0.811713    1.000000 -0.324230
# Volume         -0.039345 -0.390488 -0.390056 -0.390488   -0.324230  1.000000
# openingbalance  0.088145  0.369333  0.361648  0.369333    0.280829 -0.087025
# closingbalance  0.440989  0.346498  0.339834  0.346498    0.263699 -0.147108
# low             0.202040  0.999859  0.993859  0.999859    0.812412 -0.392209
# Unit_Sales      0.202268  0.999997  0.994002  0.999997    0.811735 -0.390505
# Total_Sales     0.196067  0.996367  0.990375  0.996367    0.808752 -0.389874
# ...

# %% [markdown]
# Correlation heatmap is graphical representation of correlation matrix representing correlation between different variables.
# The value of correlation can take any values from -1 to 1..
#
# Spearman's rank correlation Interpretation:
#
# 0 There's no correlation between the two variables
#
# -0.25 There's a small negative correlation between the two variables
#
# -0.75 There's a large negative correlation between the two variables
#
# -1.0 There's a perfect negative correlation between the two variables
#
# 0.25 There's a small positive correlation between the two variables
#
# 0.75 There's a large positive correlation between the two variables
#
# 1.0 There's a perfect positive correlation between the two variables

# %% [markdown]
# # STEP IV : Examining the relationship between categorical and dependent variables

# %%
 # Looking the categorical columns
df.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['Gender', 'Dependancies', 'Calls', 'Type', 'Billing', 'Rating', 'Education']

# %% [markdown]
# we have above categorical columns now we are going to see this variables relationship with dependent variable which is salary of employees

# %%
df.head(3)# viewing for reference.
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
#
#     Salary  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0  5089.00  2035.600  254.4500        3.77  21226600            3.75
# 1  5698.12  2279.248  284.9060        3.74  10462800            3.85
# 2  5896.65  2358.660  294.8325        3.89  18761000            4.23
#
#    closingbalance   low  Unit_Sales  Total_Sales  Months            Education
# 0            3.76  3.65       18.25        18.80       0  High School or less
# 1            3.68  3.65       18.40        18.85       0  High School or less
# 2            4.29  3.72       18.70        18.90       0  High School or less

# %% [markdown]
# # Boxplot to see Relationship Between categorical and Dependent variables

# %% [markdown]
# ### A box and whisker plot also called a box plot displays the five-number summary of a set of data. The five-number summary is the minimum, first quartile, median, third quartile, and maximum. In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median.

# %% [markdown]
# ### Box plot for gender vs salary

# %%
# We are going to groupby the Gender variable and plotting box plot 
grp3 = df.groupby('Gender')['Salary'].apply(list).to_dict()# using groupby function
plt.figure(figsize = (10,8))# figuresize
# Labeling the plot
plt.xlabel("Genger")
plt.ylabel("Salary")
plt.title("Gender vs salary")
plt.boxplot(grp3.values(),labels =  grp3.keys(),showmeans = True)
plt.show()

# %% [markdown]
# Here We see that median of both Males and Females is equal That means It is not useful in our model building.

# %%
# calculating aggregate sum of salary of male & female
gender_ = df[['Gender','Salary']].groupby(['Gender'],as_index=False).agg(sum)
gender_['Salary'] = gender_['Salary'].astype('int64') #Converting exponent or scientific number into integer
gender_
# Out:
#    Gender     Salary
# 0  Female  245375400
# 1    Male  253734241

# %% [markdown]
# We conclude that total Males salary is heigher than the total females salary
#
# we see that for female aggregate sum of salary is 245375400 and for male aggregate sum of salary is 253734241

# %% [markdown]
# ### Box plot for Business vs salary

# %%
# calculating aggregate sum of salary of each Business background
Business_= df[['Business','Salary']].groupby(['Business'],as_index=False).agg(sum)
Business_['Salary'] = Business_['Salary'].astype('int64') #Converting exponent or scientific number into integer
Business_
# Out:
#    Business     Salary
# 0         0  419639698
# 1         1   79469944

# %%
# plotting boxplot to see Salary of employees on business basis
fig = plt.figure(figsize=(12,7))

grp4 = df.groupby('Business')['Salary'].apply(list).to_dict()# using groupby function
# Labeling the plot
plt.xlabel("Business")
plt.ylabel("Salary")
plt.title("Business vs salary")
plt.boxplot(grp4.values(),labels = grp4.keys(),showmeans = True)
plt.show()

# %% [markdown]
# Here We see that median of both Buiseness 0  and Buiseness 1 is equal That means It is not useful in our model building.

# %% [markdown]
# ### Box plot for Dependancies vs salary

# %%
# calculating aggregate sum of Dependancies of Yes & No
Dependancies_= df[['Dependancies','Salary']].groupby(['Dependancies'],as_index=False).agg(sum)
Dependancies_
# Out:
#   Dependancies        Salary
# 0           No  3.514093e+08
# 1          Yes  1.477003e+08

# %%
#Boxplot to see salary on basis of Dependancies
plt.figure(figsize = (10,8))# figuresize
grp6 = df.groupby('Dependancies')['Salary'].apply(list).to_dict()# using groupby function

# Labeling the plot
plt.xlabel("Dependancies")
plt.ylabel("Salary")
plt.title("Dependancies vs salary")
plt.boxplot(grp6.values(),labels = grp6.keys(),showmeans = True)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# Here We see that median of both Dependancies Yes  and Dependancies No is equal That means It is not useful in our model building.

# %% [markdown]
# ### Box plot for Calls vs salary

# %%
# calculating aggregate sum of salary of calls yes or no
Calls_= df[['Calls','Salary']].groupby(['Calls'],as_index=False).agg(sum)
Calls_['Salary'] = Calls_['Salary'].astype('int64') #Converting exponent or scientific number into integer
Calls_
# Out:
#   Calls     Salary
# 0    No   44902230
# 1   Yes  454207412

# %%
#Boxplot to see salary on basis of Calls
plt.figure(figsize = (10,8))# figuresize
grp5 = df.groupby('Calls')['Salary'].apply(list).to_dict()# using groupby function

# Labeling the plot
plt.xlabel("Calls")
plt.ylabel("Salary")
plt.title("Calls vs salary")
plt.boxplot(grp5.values(),labels = grp5.keys(),showmeans = True)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# Here We see that median of both Calls Yes and Calls No is equal That means It is not useful in our model building.

# %% [markdown]
# ### Box plot for type(salary settlement type ) vs salary

# %%
# calculating aggregate sum of Type
type_= df[['Type','Salary']].groupby(['Type'],as_index=False).agg(sum)
type_['Salary'] = type_['Salary'].astype('int64') #Converting exponent or scientific number into integer
type_
# Out:
#              Type     Salary
# 0  Month-to-month  277309088
# 1        One year  101414600
# 2        Two year  120385953

# %% [markdown]
# Here we see that month to month type have heighest salary paid

# %%
#Boxplot to see salary on Type basis
plt.figure(figsize = (10,8))# figuresize
grp2 = df.groupby('Type')['Salary'].apply(list).to_dict()# using groupby function

# Labeling the plot
plt.xlabel("Type")
plt.ylabel("Salary")
plt.title("Type vs salary")
plt.boxplot(grp2.values(),labels = grp2.keys(),showmeans = True)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# Month-to-month type settelements are mostly done in our data.
# Here We see that median of Month to Month, One year and Two year is equal That means It is not useful in our model building.

# %% [markdown]
# ### Box plot for Billing vs salary

# %%
# calculating aggregate sum of salary of each Billing option
Billing_= df[['Billing','Salary']].groupby(['Billing'],as_index=False).agg(sum)
Billing_['Salary'] = Billing_['Salary'].astype('int64') #Converting exponent or scientific number into integer
Billing_
# Out:
#   Billing     Salary
# 0      No  203502946
# 1     Yes  295606696

# %%
# plotting boxplot to see salary on basis of Billing
fig = plt.figure(figsize=(12,7))

grp7 = df.groupby('Billing')['Salary'].apply(list).to_dict()# using groupby function
# Labeling the plot
plt.xlabel("Billing")
plt.ylabel("Salary")
plt.title("Billing vs salary")
plt.boxplot(grp7.values(),labels = grp7.keys(),showmeans = True)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# Here We see that median of both Billing Yes  and Billing No is equal That means It is not useful in our model building.

# %% [markdown]
# ### Box plot for Rating vs salary

# %%
# calculating aggregate sum of salary of Rating 
Rating_= df[['Rating','Salary']].groupby(['Rating'],as_index=False).agg(sum)
Rating_['Salary'] = Rating_['Salary'].astype('int64') #Converting exponent or scientific number into integer
Rating_
# Out:
#   Rating     Salary
# 0     No  367090717
# 1    Yes  132018924

# %%
# plotting boxplot to see Salary basis on Rating
fig = plt.figure(figsize=(12,7))

grp1 = df.groupby('Rating')['Salary'].apply(list).to_dict()# using groupby function
# Labeling the plot
plt.xlabel("Rating")
plt.ylabel("Salary")
plt.title("Rating vs salary")
plt.boxplot(grp1.values(),labels = grp1.keys(),showmeans = True)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# Here We see that median of both Rating Yes  and Rating No is equal That means It is not useful in our model building.

# %% [markdown]
# ### Box plot for Education vs salary

# %%
# calculating aggregate sum of salary of each Education background
education_= df[['Education','Salary']].groupby(['Education'],as_index=False).agg(sum)
education_['Salary'] = education_['Salary'].astype('int64') #Converting exponent or scientific number into integer
education_
# Out:
#              Education     Salary
# 0           Graduation  181628301
# 1  High School or less     112296
# 2         Intermediate     237520
# 3                   PG  317131524

# %% [markdown]
# Here also we see that PG persons have the heigest salary followed by graduation.

# %%
# plotting boxplot to see min ,max salary education wise
fig = plt.figure(figsize=(12,7))

grp1 = df.groupby('Education')['Salary'].apply(list).to_dict()# using groupby function
# Labeling the plot
plt.xlabel("Education")
plt.ylabel("Salary")
plt.title("Education vs salary")
plt.boxplot(grp1.values(),labels = grp1.keys(),showmeans = True)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# Here We see that median of all categories are not equal That means It is very useful in our model building.

# %% [markdown]
# PG persons are get heigher salary than others we see that height school or less educated persons get lowest salaries

# %% [markdown]
# # Dependent vs Numerical variables

# %% [markdown]
# ## Histogram for Age

# %% [markdown]
# age vs salary plot shows that as age increasess similarly slowly salary will also get increases

# %% [markdown]
# ## Distribution of salary on age :

# %%
#distribution of salary on age to know the trend of salary increase according to age or not . 
plt.figure(figsize=(20,10))
plt.xlabel('Age',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('age vs salary',fontsize=20)

sns.lineplot(df['Age'],df['Salary'],color='black',linewidth = 3)
plt.show()

# %% [markdown]
# Here we see that how salary is varrying with age

# %% [markdown]
# ## Scatter plot age vs salary

# %%
#distribution of salary on age to know the trend of salary increase according to age or not . 
plt.figure(figsize=(20,10))
plt.xlabel('Age',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('age vs salary',fontsize=20)

sns.scatterplot(df['Age'],df['Salary'],color='black')
plt.show()

# %% [markdown]
# By observing the above plot here we dont see any special patterns in our data there is no relationship between Age & Salary
# and By using Spearman correlation we got 0.2 correlation between salary and Age thats why im going to remove this column in feature selection.

# %% [markdown]
# ## Scatter plot volume vs salary

# %%
#distribution of salary on Volume to know the trend of salary increase according to volume or not . 
plt.figure(figsize=(20,10))
plt.xlabel('Volume',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('Volume vs salary',fontsize=20)

sns.scatterplot(df['Volume'],df['Salary'],color='black')
plt.show()

# %% [markdown]
# By observing the above plot here we dont see any special patterns in our data there is no relationship between Volume & Salary
# and By using Spearman correlation we got -39% correlation between salary and Volume thats why im going to remove this column in feature selection.

# %% [markdown]
# ## Scatter plot for bonus vs Salary

# %%
#distribution salary on basis of bonus 
plt.figure(figsize=(20,10))
plt.xlabel('Bonus',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('Bonus vs salary',fontsize=20)

sns.scatterplot(df['Bonus'],df['Salary'],color='black')
plt.show()

# %% [markdown]
# By observing the above plot here we see that we have linear relationship between Bonus and Salary
# and By using Spearman correlation we got 100% correlation between salary and bonus thats why this is important variable us

# %% [markdown]
# ## Scatter plot for Base_Pay vs Salary

# %%
#distribution of salary on the basis of Base_Pay
plt.figure(figsize=(20,10))
plt.xlabel('Base_pay',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('Bae_pay vs salary',fontsize=20)

sns.scatterplot(df['Base_pay'],df['Salary'],color='black')
plt.show()

# %% [markdown]
# By observing the above plot here we see that we have linear relationship between Base_pay and Salary but bonus & base_pay are highly collinear with each other
# thats why We are going to kept only one variable

# %% [markdown]
# ## Scatterplot for openingbalance vs salary

# %%
#distribution of salary on the basis of openingbalance
plt.figure(figsize=(20,10))
plt.xlabel('openingbalance',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('openingbalance vs salary',fontsize=20)

sns.scatterplot(df['openingbalance'],df['Salary'],color='black')
plt.show()

# %% [markdown]
# By observing the above plot here we didnt see any special patterns in our data there is no relationship between openingbalance & Salary
# and By using Spearman correlation we got 36% correlation between salary and openingbalance thats why im going to remove this column in feature selection.

# %% [markdown]
# ## Scatterplot for closingbalance vs salary

# %%
#distribution salary on the basis of closingbalance
plt.figure(figsize=(20,10))
plt.xlabel('openingbalance',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('closingbalance vs salary',fontsize=20)

sns.scatterplot(df['closingbalance'],df['Salary'],color='black')
plt.show()

# %% [markdown]
# By observing the above plot here we didnt see any special patterns in our data there is no relationship between closingbalance & Salary
# and By using Spearman correlation we got 34% correlation between salary and closingbalance thats why im going to remove this column in feature selection.

# %% [markdown]
# ## How salary increase according to the months :

# %%
#Looking the salary increase according to the months.

plt.figure(figsize=(10,8))
plt.ylabel('salary',fontsize=20)
plt.xlabel('months',fontsize=20)
plt.title('months vs salary.',fontsize=20)

sns.lineplot(df['Months'],df['Salary'],color='Navy',linewidth = 3)
plt.show()

# %% [markdown]
# As we see that salary is positively increases as months increases

# %% [markdown]
# ### Relation between all the variables :

# %%
#Looking at the relation between all the variables by using pairplot importing seaborn libary.
sns.pairplot(df)

# %% [markdown]
# By using pairplot we see that relationship of all variables some plots have linear relationship and some plots have continieus data where we able see some trends in that plot.
#
# Observing all relationships we conclude that which variables are imporant and which are not

# %% [markdown]
# # Data Cleaning:

# %% [markdown]
# ## Boxplots to see outliers :

# %% [markdown]
# In data cleaning process we previosly did some steps like Handling of missing values,Replacing NAN values with mean values etc
#
# Now We are going to handle Outliers from our dataset,and finally cleaning of our dataset

# %%
# setting a grey background 
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with variables
sns.boxplot(data=df, x="Salary", color="Lime", ax=axs[0, 0])# boxplot to see outliers of salary
sns.boxplot(data=df, x="Base_pay", color="olive", ax=axs[0, 1])# boxplot to see outliers of base_pay
sns.boxplot(data=df, x="Bonus", color="gold", ax=axs[1, 0])# boxplot to see outliers of bonus
sns.boxplot(data=df, x="Age", color="pink", ax=axs[1, 1])# boxplot to see outliers of age
plt.show()

# %% [markdown]
# Here we see that "Salary","Base_pay","Bonus","Age" this variales have outliers this outliers are for both sides means we have values which are below than min range and above than max range which is above the upperwhisker and below the lowerwhisker

# %%
# settong a grey background  
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with all variables
sns.boxplot(data=df, x="Unit_Price", color="darkred", ax=axs[0, 0])# boxplot to see outliers of unitprice 
sns.boxplot(data=df, x="Unit_Sales", color="olive", ax=axs[0, 1])# boxplot to see outliers of unit_sales
sns.boxplot(data=df, x="openingbalance", color="gold", ax=axs[1, 0])# boxplot to see outliers of openingbalance
sns.boxplot(data=df, x="closingbalance", color="teal", ax=axs[1, 1])# boxplot to see outliers of closingbalance

plt.show()

# %% [markdown]
# Here we see that "Unit_price","openingbalance","closingbalance"this variales have outliers this outliers are  above than max range or above the upperwhisker.
#
# Unit_sales dont have any outliers.

# %%
# settong a grey background  
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with variables
sns.boxplot(data=df, x="low", color="red", ax=axs[0,0])# boxplot to see outliers of low column 
sns.boxplot(data=df, x="Total_Sales", color="Navy", ax=axs[0,1])# boxplot to see outliers of Total_sales column
sns.boxplot(data=df, x="Volume", color="Yellow", ax=axs[1,0])# boxplot to see outliers of volume column
sns.boxplot(data=df, x="Months", color="skyblue", ax=axs[1,1])# boxplot to see outliers of months column
plt.show()

# %% [markdown]
# Here we see that "low"&"volume"this variales have outliers this outliers are  above than max range or above the upperwhisker
#
# Total_sales & Months dont have any outliers.

# %% [markdown]
# ### As we see that we have many outliers in our dataset.If we remove/replace that all outliers then we are uable to create a desired model on the dataset. So first I thought of using decision tree & random forest models Because trees divide items by lines, so it does not difference how far is a point from lines.
#
# ### All tree algorithms are robust to outliers and Tree algorithms split the data points on the basis of same value and so value of outlier won't affect that much to the split.

# %% [markdown]
# # Feature Selection

# %% [markdown]
# # Now Working on Numerically Highly corelated variables

# %% [markdown]
# From Heatmap I conclude that Some of our numerical variables have very high correlation between them which is above 80% coliniarity between dependent and other variables.
#
# Using scatter plot also we saw that relationship between independent and dependent variables

# %%
# Looking to the percentage of correlation 
df3.corr(method='spearman')*100
# Out:
#                        Age      Salary    Base_pay       Bonus  Unit_Price  \
# Age             100.000000   20.228180   19.293007   20.228180   12.826637
# Salary           20.228180  100.000000   99.400565  100.000000   81.171311
# Base_pay         19.293007   99.400565  100.000000   99.400565   80.831086
# Bonus            20.228180  100.000000   99.400565  100.000000   81.171311
# Unit_Price       12.826637   81.171311   80.831086   81.171311  100.000000
# Volume           -3.934477  -39.048779  -39.005604  -39.048779  -32.422983
# openingbalance    8.814546   36.933307   36.164750   36.933307   28.082928
# closingbalance   44.098882   34.649833   33.983373   34.649833   26.369923
# low              20.203950   99.985870   99.385860   99.985870   81.241207
# Unit_Sales       20.226808   99.999741   99.400221   99.999741   81.173482
# Total_Sales      19.606722   99.636720   99.037490   99.636720   80.875162
# ...

# %% [markdown]
# ### Here we see that Base_pay, Bonus, Unit_Price, low, Unit_sales, Total_Sales This variables are heighly corelated with each other.

# %% [markdown]
# So we have two options either we can choose one variable and delete the remaing variables or going to take average of that columns

# %% [markdown]
# So here I observed that between this colinear variables 'bonus' have high correlation with dependent variable thats why I choose to kept it and decided to delete the other variables which are highly corelated

# %%
#Droping the highly correlated columns
dff = df.drop(columns=['Base_pay','Unit_Price','low','Unit_Sales','Total_Sales'])

# %%
dff.head()
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
#
#     Salary     Bonus    Volume  openingbalance  closingbalance  Months  \
# 0  5089.00  254.4500  21226600            3.75            3.76       0
# 1  5698.12  284.9060  10462800            3.85            3.68       0
# 2  5896.65  294.8325  18761000            4.23            4.29       0
# 3  6125.12  306.2560  66130600            4.26            4.31       0
# 4  6245.00  312.2500  26868200            4.79            4.41       1
#
#              Education
# 0  High School or less
# 1  High School or less
# ...

# %% [markdown]
# We remove this columns because those columns are highly correlated with each other they will be give the same information to our model thats why i remove that columns

# %% [markdown]
# # Now Working on Categorical Features

# %% [markdown]
# As per our visualization approach we conclude that Gender,Business,Dependancies,Calls,Type,Billing,Rating This variables dont affect on our dependent variable so as per this approach Im going to remove this columns

# %%
# Dropping the non-required variables
dff = df.drop(columns=['Gender','Business','Dependancies','Calls','Type','Billing','Rating','Age','Base_pay','Unit_Price','low','Unit_Sales','Total_Sales','openingbalance','closingbalance','Volume'])
dff.head()
# Out:
#     Salary     Bonus  Months            Education
# 0  5089.00  254.4500       0  High School or less
# 1  5698.12  284.9060       0  High School or less
# 2  5896.65  294.8325       0  High School or less
# 3  6125.12  306.2560       0  High School or less
# 4  6245.00  312.2500       1  High School or less

# %% [markdown]
# Finally After removing numerical categorical less important variables we have 4 variables to build model

# %% [markdown]
# # Preprocessing of Data :

# %% [markdown]
# #### We should have only numarical columns to build a model so we have to convert all the categorical columns to numerical columns using LabelEncoding,Creating Dummy variables,Frequency Encoding,HashingEncoder,Mapping of data..etc

# %%
# Here I use Map function rather than other labeling methods
dff['Education'] = dff['Education'].map({'High School or less': 0, 'Intermediate': 1, 'Graduation': 2 ,'PG':3})

# %%
dff.head()
# Out:
#     Salary     Bonus  Months  Education
# 0  5089.00  254.4500       0          0
# 1  5698.12  284.9060       0          0
# 2  5896.65  294.8325       0          0
# 3  6125.12  306.2560       0          0
# 4  6245.00  312.2500       1          0

# %%
dff.info()# cross checking
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Salary     5000 non-null   float64
#  1   Bonus      5000 non-null   float64
#  2   Months     5000 non-null   int64
#  3   Education  5000 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 156.4 KB

# %% [markdown]
# Now our data is ready for model building so we are going to check the accuracy of different models

# %% [markdown]
# # Normalization

# %%
dff.head()#Cross check
# Out:
#     Salary     Bonus  Months  Education
# 0  5089.00  254.4500       0          0
# 1  5698.12  284.9060       0          0
# 2  5896.65  294.8325       0          0
# 3  6125.12  306.2560       0          0
# 4  6245.00  312.2500       1          0

# %% [markdown]
# # Handaling Outliers

# %% [markdown]
# ## Handing outliers of salary

# %%
#Checking the outliers in column Salary using boxplot and we found outliers over upperwhisker and lowerwhisler.
sns.boxplot(dff['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
#To check all the statistical values of Salary column
dff['Salary'].describe()
# Out:
# count      5000.000000
# mean      99821.928553
# std       25376.961744
# min        5089.000000
# 25%       83890.338980
# 50%      100579.378500
# 75%      116912.092475
# max      199970.740000
# Name: Salary, dtype: float64

# %%
#Calculating the quantiles of Age
q1 = np.quantile(dff['Salary'],0.25)
q2 = np.quantile(dff['Salary'],0.50)
q3 = np.quantile(dff['Salary'],0.75)

# %%
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
# Out:
# q1 = 83890.33898 |q2 = 100579.37849999999|q3 = 116912.092475

# %%
#Calculating IQR(linear quadratic regulator)
IQR = q3-q1
IQR
# Out:
# 33021.753495

# %%
#Calculating the Upperwhisker and lowerwhisker.
Upperwhisker = q3+(1.5*IQR)
Lowerwhisker = q1-(1.5*IQR)

# %%
#Displaying all the columns which have outliers.
dff[(dff.Salary<Lowerwhisker)|(dff.Salary>Upperwhisker)]
# Out:
#          Salary      Bonus  Months  Education
# 0       5089.00   254.4500       0          0
# 1       5698.12   284.9060       0          0
# 2       5896.65   294.8325       0          0
# 3       6125.12   306.2560       0          0
# 4       6245.00   312.2500       1          0
# ...         ...        ...     ...        ...
# 4995  180696.80  9034.8400      72          3
# 4996  185685.90  9284.2950      72          3
# 4997  192636.80  9631.8400      72          3
# 4998  195970.70  9798.5350      72          3
# 4999  199970.74  9998.5370      72          3
#
# [77 rows x 4 columns]

# %%
#Replaying outliers into upperwhisker and lowerwhisker
dff['Salary'] = dff['Salary'][(dff['Salary'] >= Lowerwhisker) & (dff['Salary'] <= Upperwhisker)]

# %%
#Checking the outliers in column Salary using boxplot.
sns.boxplot(dff['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
dff['Salary'].shape
# Out:
# (5000,)

# %%
dff['Salary'].isnull().sum()
# Out:
# 77

# %%
# replacing missing values of Base_pay with mean of that column
dff['Salary'] = dff['Salary'].fillna(dff['Salary'].mean())

# %%
dff['Salary'].describe()# Here we see that our Mean = Median
# Out:
# count      5000.000000
# mean     100799.611045
# std       23016.047770
# min       34852.950000
# 25%       84784.862373
# 50%      100799.611045
# 75%      116693.493925
# max      165132.485900
# Name: Salary, dtype: float64

# %%
dff['Salary'].isnull().sum()# Cross cheking the null values
# Out:
# 0

# %%
sns.boxplot(dff['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
#checking the normal distribution for salary
sns.histplot(data=dff, x="Salary", kde=True, color="Black")
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Count'>

# %% [markdown]
# After replacing the outliers with mean values now we have normally distributed variable

# %% [markdown]
# ## Handling outliers of Bonus

# %%
sns.boxplot(dff['Bonus'])
# Out:
# <AxesSubplot:xlabel='Bonus'>

# %%
#Applying all the operations to work on outliers as worked on above columns.
q1 = np.quantile(dff['Bonus'],0.25)
q2 = np.quantile(dff['Bonus'],0.50)
q3 = np.quantile(dff['Bonus'],0.75)
print(f'q1 = {q1} |q2 = {q2}|q3 = {q3}')
IQR = q3-q1
IQR
Upperwhisker = q3+(1.5*IQR)
Lowerwhisker = q1-(1.5*IQR)
dff['Bonus'] = dff['Bonus'][(dff['Bonus'] >= Lowerwhisker) & (dff['Bonus'] <= Upperwhisker)]
sns.boxplot(df['Bonus'])
# Out:
# q1 = 4194.5169495 |q2 = 5028.968925|q3 = 5845.60462375
# <AxesSubplot:xlabel='Bonus'>

# %%
dff['Bonus'].isnull().sum()
# Out:
# 77

# %%
# replacing missing values of Bonus with mean of that column
dff['Bonus'] = dff['Bonus'].fillna(dff['Bonus'].mean())

# %%
dff['Bonus'].isnull().sum()
# Out:
# 0

# %%
dff['Salary'].describe()# Here we see that our Mean = Median
# Out:
# count      5000.000000
# mean     100799.611045
# std       23016.047770
# min       34852.950000
# 25%       84784.862373
# 50%      100799.611045
# 75%      116693.493925
# max      165132.485900
# Name: Salary, dtype: float64

# %%
#checking the normal distribution for the bonus
sns.histplot(data=dff, x="Bonus", kde=True, color="darkred")
# Out:
# <AxesSubplot:xlabel='Bonus', ylabel='Count'>

# %% [markdown]
# ### Observing outliers of Months

# %%
sns.boxplot(dff['Months'])
# Out:
# <AxesSubplot:xlabel='Months'>

# %% [markdown]
# In Month we dont have any outlier

# %%
dff.head()
# Out:
#           Salary        Bonus  Months  Education
# 0  100799.611045  5039.980552       0          0
# 1  100799.611045  5039.980552       0          0
# 2  100799.611045  5039.980552       0          0
# 3  100799.611045  5039.980552       0          0
# 4  100799.611045  5039.980552       1          0

# %%
'''from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
### fit vs fit_transform
dff5=scaler.fit_transform(dff)
dff5 = pd.DataFrame(dff)
dff5 = dff5.rename(columns = {0:'Salary',1:'Bonus',2:'Months',3:'Education'})
dff5'''
# Out:
# "from sklearn.preprocessing import StandardScaler\nscaler=StandardScaler()\n### fit vs fit_transform\ndff5=scaler.fit_transform(dff)\ndff5 = pd.DataFrame(dff)\ndff5 = dff5.rename(columns = {0:'Salary',1:'Bonus',2:'Months',3:'Education'})\ndff5"

# %% [markdown]
# # Model Building

# %% [markdown]
# Dividing data into train test split model

# %%
#Independent variables to x
x =dff.drop(['Salary'],axis=1)

# %% [markdown]
# Droping independent of target variable and taking all the remaining variables

# %%
#Dependent variables to y
y = dff['Salary']

# %%
#Importing train_test_split from sklearn.model_selection to test and train the model 
from sklearn.model_selection import train_test_split

# %%
# Giving the test size as 0.30(30%) which makes train size as 0.70(70%) as default and random state as 1.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=1)

# %%
#Checking the shape of x_test.
x_test.shape
# Out:
# (1000, 3)

# %%
#Checking the shape of x_train.
x_train.shape
# Out:
# (4000, 3)

# %%
#Checking the shape of y_test.
y_test.shape
# Out:
# (1000,)

# %%
# data normalization with sklearn
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
# fit scaler on training data
x_train = sc.fit_transform(x_train)

# transform testing dataabs
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.74972169,  1.57088252,  0.78755786],
#        [-0.86379543,  1.20511442, -1.14628588],
#        [-0.44823576, -1.23333953,  0.78755786],
#        ...,
#        [-0.96989305,  0.71742363, -1.14628588],
#        [ 0.83450871,  0.79870543,  0.78755786],
#        [-1.89256015, -1.11141683,  0.78755786]])

# %%
x_test
# Out:
# array([[ 0.12582318, -0.58308514,  0.78755786],
#        [ 1.69095643,  1.57088252,  0.78755786],
#        [ 0.73912241,  0.59550094, -1.14628588],
#        ...,
#        [ 0.90878859,  0.92062813,  0.78755786],
#        [-0.74041936,  1.57088252,  0.78755786],
#        [-0.13993295, -0.98949413, -1.14628588]])

# %% [markdown]
# # Decision Tree Regression :

# %% [markdown]
# ### Regression trees have a continuous target variable. Decision trees, while often used to describe both regression and classification, usually refer to categorical target variables (classification ).

# %%
#Importing DecisionTreeRegressor from sklearn.tree library.
from sklearn.tree import DecisionTreeRegressor
#Calling DecisionTreeRegressor with max_depth as 3 and calling it to dt.
dt= DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# "The maximum depth of the tree(max_depth). If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples."
#
# If we don't provide max_depth so it should take the value that has maximum leaves.

# %%
#Fitting x_train,y_train to dt.
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
# Score of train model
print(dt.score(x_train, y_train))
#score of test model.
print(dt.score(x_test, y_test))
# Out:
# 0.9691777355988367
# 0.9702843586143122

# %%
#By using dt.predict function on x_test and calling it to y_predict to predict a value 
y_pred=dt.predict(x_test)

# %%
print(y_pred)# cheking the predicted values
# Out:
# [104704.95428303 146034.45401511 116086.72536333 116086.72536333
#  104704.95428303 116086.72536333 104704.95428303  83070.07654847
#   83070.07654847  70799.43057993  94754.90764824  83070.07654847
#   94754.90764824 116086.72536333 116086.72536333 116086.72536333
#  104704.95428303 116086.72536333  94754.90764824  70799.43057993
#   94754.90764824 116086.72536333 146034.45401511 104704.95428303
#   83070.07654847  83070.07654847 129223.47514805 129223.47514805
#  104704.95428303 104704.95428303  83070.07654847 116086.72536333
#   70799.43057993  83070.07654847  70799.43057993 104704.95428303
#  104704.95428303 104704.95428303  83070.07654847  94754.90764824
#   83070.07654847  94754.90764824 116086.72536333  94754.90764824
#  129223.47514805  70799.43057993  83070.07654847  83070.07654847
#  116086.72536333 116086.72536333 116086.72536333 104704.95428303
#   83070.07654847 104704.95428303  94754.90764824 129223.47514805
# ...

# %%
#Importing metrices from sklearn library
from sklearn import metrics
#Metrix gives r2 score to cross verify accuracy of model

# %%
#cheking the r2_score to y_test,y_predict to predict the accuracy.
r_square=metrics.r2_score(y_test,y_pred)
print('R-square error for decision tree regressor is:',round(100*(r_square),3))
# Out:
# R-square error for decision tree regressor is: 97.028

# %% [markdown]
# R-square error use to predict the accuracy.

# %%
#By using dt.predict function on x_test and calling it to y_predict to predict a value 
y_pred=dt.predict(x_test)
#Importing metrices from sklearn library
from sklearn import metrics
#Applying r2_score to y_test,y_predict to predict the accuracy and print the accuracy percentage.
r_square=metrics.r2_score(y_test,y_pred)
print('R-square error associated with decision tree regressor is:',round(100*(r_square),2))
# Out:
# R-square error associated with decision tree regressor is: 97.03

# %% [markdown]
# ## Cross-Validation & Performance Check

# %%
#Calculating mean absolute error, mean squared error, root mean squared error, mean absolute percentage error and accuracy on y_test and y_predict.
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
mape = np.mean(np.abs((y_test-y_pred) / np.abs(y_test)))
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(100*(1 - mape), 2))
# Out:
# Mean Absolute Error (MAE): 3224.5996412838817
# Mean Squared Error (MSE): 15528797.59286459
# Root Mean Squared Error (RMSE): 3940.65953780133
# Mean Absolute Percentage Error (MAPE): 3.52
# Accuracy: 96.48

# %% [markdown]
# # Decision tree regressor is: 97.03

# %% [markdown]
# We got the 97.03 percent accuracy by using decision tree regression model

# %% [markdown]
# ### Plotting the tree

# %%
'''#Importing tree from sklearn to display data visualization of DecisionTreeRegressor and plotting the tree of x_train columns.
from sklearn import tree
plt.figure(figsize=(30,20))
tree.plot_tree(dt, feature_names = x_train.columns, max_depth=3, filled=True)
plt.show()'''
# Out:
# '#Importing tree from sklearn to display data visualization of DecisionTreeRegressor and plotting the tree of x_train columns.\nfrom sklearn import tree\nplt.figure(figsize=(30,20))\ntree.plot_tree(dt, feature_names = x_train.columns, max_depth=3, filled=True)\nplt.show()'

# %% [markdown]
# Here we have Bonus as our root node

# %% [markdown]
# # Random Forest Regression :

# %%
#Importing RandomForestRegressor from sklearn.ensemble.
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor(random_state=5) 
RF.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=5)

# %% [markdown]
# "If we don't specify the random_state in the code, then every time when we run(execute) our code a new random value is generated and the train and test datasets would have different values each time."

# %%
#By using RT.predict function on x_test and calling it to y_predict to predict a value
y_predict = RF.predict(x_test)

# %%
#Calculating mean absolute error, mean squared error, root mean squared error, mean absolute percentage error and accuracy on y_test and y_predict.
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test,y_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test,y_predict))
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
mape = np.mean(np.abs((y_test-y_predict) / np.abs(y_test)))
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(100*(1 - mape), 2))
# Out:
# Mean Absolute Error (MAE): 13.421898716669086
# Mean Squared Error (MSE): 1144.6864175498476
# Root Mean Squared Error (RMSE): 33.8332147090673
# Mean Absolute Percentage Error (MAPE): 0.02
# Accuracy: 99.98

# %% [markdown]
# # RandomForestRegresser Accuracy : 99.92

# %% [markdown]
# ### Now we are trying to calculate R_score using n_estimators method

# %%
#Importing RandomForestRegressor from sklearn.ensemble.
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=7)# here we choose 7 trees only 
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=7)

# %% [markdown]
# ### n_estimators is the number of trees
# we want to build before taking the maximum voting or averages of predictions. Higher number of trees give us better performance but makes our code slower.

# %%
#Applying score to x_train, y_train.
rf.score(x_train, y_train)
# Out:
# 0.9999987865968948

# %%
#Applying score to x_test, y_test.
rf.score(x_test, y_test)
# Out:
# 0.9999982901877676

# %% [markdown]
# # Linear Regresion model

# %%
# Importing 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Cheking the shape of x_test
x_test.shape
# Out:
# (1000, 3)

# %%
# loading linearregression model 
reg_model=LinearRegression()

# %%
reg_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Model evaluation for training set
y_predict = reg_model.predict(x_train)

# %%
rmse = (np.sqrt(mean_squared_error(y_train,y_predict)))
print(rmse)
from sklearn.metrics import r2_score
r2_score(y_train,y_predict)
# Out:
# 3.734370371060358e-06
# 1.0

# %%
# Prediction on test data
y_testpredict = reg_model.predict(x_test)

# %%
# Cheking the score of model using testing data
r2=r2_score(y_test,y_testpredict)
r2
# Out:
# 1.0

# %% [markdown]
# ### By appling linear regression model we see that we got 100% accuracy practically this is possible only when we have independent variables which are highly correlated with the target variable and the results wouldn't be surprising at all.
#
# ### In our Model Bonus and Salary having the 1 coliniarity thats why our model build with 100% Accuracy

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
k_range = list(range(1, 31)) #taking 30 iteration

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import ShuffleSplit
model=DecisionTreeRegressor()
ssplit=ShuffleSplit(n_splits=30,test_size=0.30)
results=cross_val_score(model,x_train, y_train,cv=ssplit)

# %%
results# prediced results
# Out:
# array([0.99998785, 0.9999938 , 0.99999348, 0.99999129, 0.99999366,
#        0.99999337, 0.99999149, 0.99999278, 0.99999105, 0.99999165,
#        0.99999276, 0.99999545, 0.99999565, 0.99999565, 0.99999345,
#        0.99999272, 0.99999207, 0.99998776, 0.99999663, 0.99999474,
#        0.99998811, 0.99999331, 0.99999033, 0.99999601, 0.99999403,
#        0.99999507, 0.99999247, 0.99999263, 0.99998974, 0.99999252])

# %%
np.mean(results)# mean result
# Out:
# 0.9999927178058424

# %%
# plot the value of K for decisiontress regressor (x-axis) versus the cross-validated accuracy (y-axis)
plt.plot(k_range, results)
plt.xlabel('Value of K for Decission tree regressor')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %% [markdown]
# Here in cross validation we see that our Accuracy lie between 8.4 to 9.6 that means our project get better performance

# %% [markdown]
# # Result :

# %% [markdown]
# Finaly By applying Random Forest Regressor Model , Decision Tree Regressor Model & linear Regression Model
# we got accuracy like.
# ## #Decision Tree Regressor is: 97.03
# ## #Random Forest Regressor Accuracy: 99.98
# ## #Linear Regression is : 100

# %% [markdown]
# # Result:

# %% [markdown]
# ### Here In our project  we focus on Bonus variable becuase Unit_sales, Unit_price, Total_sales thtis three variables are directly relate to Bonus columns as our Total_sales increases similarly Bonus will also get increases and Bonus and Salary are 100% corelated with each other thats Why I take Bonus as a main independent column.
#
#
#
#
#
# 1.Most of the employee are seniors with mean age of 51.
#
# 2.Few data normalization checked,and they were not normal.It means they have outliers.
#
# 3 Spearman co-relation was obtained.Spearmen correlation between salary and Bonus is 0.99.
#
# 3.a. It means it is Perfectly monotonically increasing relationship and salary linearly increases with Bonus.
#
# 3.b. We can depict that employee who will do high Bonus will get higher salary.Similary all features can be related in spearman table.
#
# 4 Cateograical and dependent variable analyzed.
#
# Both Male and female working in almost equal number in the company.
# 6.We can depicts from this graph that both female and male drawing almost equal salary(total number wise) from company.
#
# Mean of the both person who has business or not is almost same.
# 7.Large number of employee have authority to call.
#
# We can observe that employee with PG degree draws salary approximately ranges from almost 50000 to 2 lac. Employee with Graduation is drawing salary from approximately 25000 to 1.25 lac. Salary of High School or less and Intermediate is drawing salary less than 25000.
# 8.We can observe that high number of unit sales ,higher will be the salary.
#
# 9.We can see that higher number of sales similarly higher the bonus & higher is the salary.
#
# 10.we can observe that company has hired high number of new employees. In last four months company has hired.
# almost 765 employees. Also company has 269 employees who are giving there services from 72 months.
#
# we can observe here that employess who are 40 to 63 years old are in large number.Also above we observed that company.
# hired good number of new employess so we can relate that companies are hiring experience candidates more .

# %% [markdown]
# # How salary is varrying with respect to other considerable variables / Recommendations

# %% [markdown]
# #### 1) Main Considerable Numerical variables are Base_pay, Bonus, low, Total_sales, Unit_price, Unit_sales.(So this all variables are highly collinear with other and with Salary. )
#
# #### 2) Salary highly affected by Bonus(Total_sales, Unit_price, Unit_sales), Month & Education.
#
# #### 3) Similiarly we have to focus on some categorical variables like "Education" becuase our salary is also depend on it.
#
# #### 4) Month variable is also important becuase salary will get change as months will get increase or decrease.
#
# #### 5) The remaning categorical variables like Gender, Business, Calls, Rating, Dependancies This variables are not that much       important.
#
# #### 6) Same The remaining numerical variables like openingbalance, closingbalance, volume, Age this variables are affect on our
#    #### salary but very less amount thats why it is not necessary to focus on this variables.

# %% [markdown]
# # Recommendations

# %% [markdown]
# -From the analysis done, it was observed that employee with high experience giving high sales to the company. So company should hire experienced candidate more.
#
# -Employee performance was dominated by months(services to the company), education.
#
# -So strategic approach to the efficient management and maximum business gain to the company can be done by hiring the employee who is experienced and has high education like PG.
#
# -Salary component mostly affected by the months and education.Also company Bonus are direcly related to salary.
#
# -So hr department can plan their approach by keeping above facts in mind for hiring the candidate who can help them to get maximum sales,which can benift the company most.
#
# _ We can directly go through either linear Redression Model or RandomForest Regression Models
